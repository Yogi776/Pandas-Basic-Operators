# %%
import pandas

# %%
data=pandas.read_csv('IBM data.csv')

# %%
data.shape
# Out:
# (1470, 35)

# %%
#the info() function helps to have an information of the data type and columns names
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
# Age                         1470 non-null int64
# Attrition                   1470 non-null object
# BusinessTravel              1470 non-null object
# DailyRate                   1470 non-null int64
# Department                  1470 non-null object
# DistanceFromHome            1470 non-null int64
# Education                   1470 non-null int64
# EducationField              1470 non-null object
# EmployeeCount               1470 non-null int64
# EmployeeNumber              1470 non-null int64
# EnvironmentSatisfaction     1470 non-null int64
# Gender                      1470 non-null object
# HourlyRate                  1470 non-null int64
# JobInvolvement              1470 non-null int64
# JobLevel                    1470 non-null int64
# JobRole                     1470 non-null object
# JobSatisfaction             1470 non-null int64
# ...

# %%
data.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department',
#        'DistanceFromHome', 'Education', 'EducationField', 'EmployeeCount',
#        'EmployeeNumber', 'EnvironmentSatisfaction', 'Gender', 'HourlyRate',
#        'JobInvolvement', 'JobLevel', 'JobRole', 'JobSatisfaction',
#        'MaritalStatus', 'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked',
#        'Over18', 'OverTime', 'PercentSalaryHike', 'PerformanceRating',
#        'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel',
#        'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance',
#        'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager'],
#       dtype='object')

# %%
#The head() function by default displays the first five records
data.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# ...

# %%
data.head(8)
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
# 5   32        No  Travel_Frequently       1005  Research & Development
# 6   59        No      Travel_Rarely       1324  Research & Development
# 7   30        No      Travel_Rarely       1358  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# ...

# %%
data[['Age','EducationField']].tail()
# Out:
#       Age EducationField
# 1465   36        Medical
# 1466   39        Medical
# 1467   27  Life Sciences
# 1468   49        Medical
# 1469   34        Medical

# %%
data.values[1,4:7]
# Out:
# array(['Research & Development', 8, 1], dtype=object)

# %%
data.values[0:3,2:5]
# Out:
# array([['Travel_Rarely', 1102, 'Sales'],
#        ['Travel_Frequently', 279, 'Research & Development'],
#        ['Travel_Rarely', 1373, 'Research & Development']], dtype=object)

# %%
data.head(3)
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# 0  ...                         1            80                 0
# 1  ...                         4            80                 1
# 2  ...                         2            80                 0
#
#    TotalWorkingYears  TrainingTimesLastYear WorkLifeBalance  YearsAtCompany  \
# ...

# %%
data.describe()
# Out:
#                Age    DailyRate  DistanceFromHome    Education  EmployeeCount  \
# count  1470.000000  1470.000000       1470.000000  1470.000000         1470.0
# mean     36.923810   802.485714          9.192517     2.912925            1.0
# std       9.135373   403.509100          8.106864     1.024165            0.0
# min      18.000000   102.000000          1.000000     1.000000            1.0
# 25%      30.000000   465.000000          2.000000     2.000000            1.0
# 50%      36.000000   802.000000          7.000000     3.000000            1.0
# 75%      43.000000  1157.000000         14.000000     4.000000            1.0
# max      60.000000  1499.000000         29.000000     5.000000            1.0
#
#        EmployeeNumber  EnvironmentSatisfaction   HourlyRate  JobInvolvement  \
# count     1470.000000              1470.000000  1470.000000     1470.000000
# mean      1024.865306                 2.721769    65.891156        2.729932
# ...

# %%
data[data['DailyRate']!=1400].head(3)
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# 0  ...                         1            80                 0
# 1  ...                         4            80                 1
# 2  ...                         2            80                 0
#
#    TotalWorkingYears  TrainingTimesLastYear WorkLifeBalance  YearsAtCompany  \
# ...

# %%
data[(data['DailyRate']==1400) & (data['Department']=='Sales') ]
# Out:
#      Age Attrition BusinessTravel  DailyRate Department  DistanceFromHome  \
# 834   34        No  Travel_Rarely       1400      Sales                 9
#
#      Education EducationField  EmployeeCount  EmployeeNumber  ...  \
# 834          1  Life Sciences              1            1163  ...
#
#      RelationshipSatisfaction StandardHours  StockOptionLevel  \
# 834                         1            80                 0
#
#      TotalWorkingYears  TrainingTimesLastYear WorkLifeBalance  YearsAtCompany  \
# 834                  6                      3               2               6
#
#     YearsInCurrentRole  YearsSinceLastPromotion  YearsWithCurrManager
# 834                  5                        1                     3
#
# [1 rows x 35 columns]

# %%
data[(data['DailyRate']==1400) & (data['BusinessTravel']=='Travel_Rarely') ]
# Out:
#      Age Attrition BusinessTravel  DailyRate              Department  \
# 85    56        No  Travel_Rarely       1400  Research & Development
# 834   34        No  Travel_Rarely       1400                   Sales
#
#      DistanceFromHome  Education EducationField  EmployeeCount  \
# 85                  7          3  Life Sciences              1
# 834                 9          1  Life Sciences              1
#
#      EmployeeNumber  ...  RelationshipSatisfaction StandardHours  \
# 85              112  ...                         1            80
# 834            1163  ...                         1            80
#
#      StockOptionLevel  TotalWorkingYears  TrainingTimesLastYear  \
# 85                  0                 37                      3
# 834                 0                  6                      3
#
#     WorkLifeBalance  YearsAtCompany YearsInCurrentRole  \
# 85                2               6                  4
# ...

# %%
data[(data['DailyRate']>=1400) |  (data['Age']>=60) ]
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 31     44        No      Travel_Rarely       1459  Research & Development
# 51     28       Yes      Travel_Rarely       1434  Research & Development
# 52     44        No      Travel_Rarely       1488                   Sales
# 54     26        No      Travel_Rarely       1443                   Sales
# 63     59        No      Travel_Rarely       1435                   Sales
# 85     56        No      Travel_Rarely       1400  Research & Development
# 105    59        No         Non-Travel       1420         Human Resources
# 110    51        No  Travel_Frequently       1456  Research & Development
# 117    36        No  Travel_Frequently       1467                   Sales
# 146    30        No      Travel_Rarely       1427  Research & Development
# 152    53        No      Travel_Rarely       1436                   Sales
# 155    29        No         Non-Travel       1496  Research & Development
# ...

# %%
data['DailyRate'].sum()
# Out:
# 1179654

# %%
data['DailyRate'].min()
# Out:
# 102

# %%
data['DailyRate'].max()
# Out:
# 1499

# %%
data['DailyRate'].mean()
# Out:
# 802.4857142857143

# %%
data['DailyRate'].median()
# Out:
# 802.0

# %%
data['Department'].unique()
# Out:
# array(['Sales', 'Research & Development', 'Human Resources'], dtype=object)

# %%
data['Department'].nunique()
# Out:
# 3

# %%
data['EducationField'].nunique()
# Out:
# 6

# %%
data['EducationField'].unique()
# Out:
# array(['Life Sciences', 'Other', 'Medical', 'Marketing',
#        'Technical Degree', 'Human Resources'], dtype=object)

# %%
data['DailyRate'].groupby([data['Department']]).median()
# Out:
# Department
# Human Resources           788.0
# Research & Development    810.0
# Sales                     770.5
# Name: DailyRate, dtype: float64

# %%
data['DailyRate'].groupby([data['Department']]).count()
# Out:
# Department
# Human Resources            63
# Research & Development    961
# Sales                     446
# Name: DailyRate, dtype: int64

# %%
data['Age'].groupby([data['Department']]).mean()
# Out:
# Department
# Human Resources           37.809524
# Research & Development    37.042664
# Sales                     36.542601
# Name: Age, dtype: float64

# %%
data['Age'].groupby([data['EducationField']]).min()
# Out:
# EducationField
# Human Resources     24
# Life Sciences       18
# Marketing           18
# Medical             18
# Other               19
# Technical Degree    19
# Name: Age, dtype: int64

# %%
data['Age'].groupby([data['EducationField']]).max()
# Out:
# EducationField
# Human Resources     59
# Life Sciences       60
# Marketing           60
# Medical             60
# Other               53
# Technical Degree    59
# Name: Age, dtype: int64

# %%
data.agg({'Age':'mean','DailyRate':'min', 'DistanceFromHome':'max'})
# Out:
# Age                  36.92381
# DailyRate           102.00000
# DistanceFromHome     29.00000
# dtype: float64

# %%
data.groupby([data['EducationField']]).agg({'Age':'mean','DailyRate':'min', 'DistanceFromHome':'max'})
# Out:
#                         Age  DailyRate  DistanceFromHome
# EducationField
# Human Resources   37.037037        106                26
# Life Sciences     37.107261        102                29
# Marketing         37.924528        118                29
# Medical           36.838362        109                29
# Other             35.365854        116                29
# Technical Degree  36.121212        107                29
